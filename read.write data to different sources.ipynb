# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'China')
china_df = df.loc[filt]
china_df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 56                             I am a developer by profession       No
# 86          I am not primarily a developer, but I write co...      Yes
# 204                    I am a student who is learning to code      Yes
# 575                            I am a developer by profession      Yes
# 841                            I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 56                                                      Never
# 86                                 Once a month or more often
# 204         Less than once a month but more than once per ...
# 575         Less than once a month but more than once per ...
# 841         Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
china_df.to_csv('china_data.csv')

# %%
china_df.to_csv('china_data.csv', sep='\t')

# %%
china_df.to_excel('china_data.xlsx')

# %%
china_df.to_json('china_data.json', orient='records', lines=True)

# %%
test = pd.read_json('china_data.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                           MainBranch Hobbyist  \
# 0                     I am a developer by profession       No
# 1  I am not primarily a developer, but I write co...      Yes
# 2             I am a student who is learning to code      Yes
# 3                     I am a developer by profession      Yes
# 4                     I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3  Less than once a month but more than once per ...
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
china_df.to_sql('sample_table', engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
